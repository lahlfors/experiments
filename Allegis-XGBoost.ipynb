# %%
USER_FLAG = "--user"

# %%
! pip install {USER_FLAG} --upgrade google-cloud-aiplatform

# %%
! pip install {USER_FLAG} --upgrade google-cloud-storage

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('gs://laah-allegis/hackathon_data.csv')

# %%
df.head()

# %%
columns=list(df.columns.values)

# %%
new_columns = [s.replace(" ", "_") for s in columns]

# %%
new_columns

# %%
df2=pd.read_csv('gs://laah-allegis/hackathon_data.csv', names=new_columns, skiprows=2)

# %%
#Use pd.to_datetime():

df2['WEEK_ENDING_DATE'] = pd.to_datetime(df2['WEEK_ENDING_DATE'])

# %%
df2=df2.drop(['DMONAME', 'WEEK_ENDING_DATE'], axis=1)

# %%
df2.head()
# Out:
#    DIVISION_NAME WEEK_ENDING_DATE  PROD_STAFF_CONTRACTOR_HC_AMT  \
# 0              3       2017-01-07                           185
# 1              9       2017-01-07                            57
# 2              4       2017-01-07                            33
# 3              7       2017-01-07                           299
# 4              0       2017-01-07                            30
#
#    RECRUITER_TOTAL_CONTACTS_AMT  RETAIL_CONTRACTOR_HC_AMT  \
# 0                           497                       163
# 1                             0                        53
# 2                           224                        33
# 3                           569                       267
# 4                           255                        30
#
#    RECRUIT_CONTRACTOR_HC_AMT  RECRUITER_ACCOUNT_INTERVIEWS_AMT  PRODUCER_HC  \
# 0                         27                                 4           19
# ...

# %%
df2.describe()
# Out:
#        DIVISION_NAME  PROD_STAFF_CONTRACTOR_HC_AMT  \
# count    1087.000000                   1087.000000
# mean        4.770009                    747.565777
# std         3.279000                    829.105458
# min         0.000000                      0.000000
# 25%         2.000000                     98.000000
# 50%         4.000000                    266.000000
# 75%         7.000000                   1386.000000
# max        10.000000                   3024.000000
#
#        RECRUITER_TOTAL_CONTACTS_AMT  RETAIL_CONTRACTOR_HC_AMT  \
# count                   1087.000000               1087.000000
# mean                    1997.000920                623.264029
# std                     2545.355437                643.499652
# min                        0.000000                  0.000000
# 25%                        0.000000                 98.000000
# 50%                      518.000000                392.000000
# 75%                     3748.500000               1050.000000
# ...

# %%
df2.dtypes

# %%
df2.isnull().sum()
# Out:
# DIVISION_NAME                       0
# WEEK_ENDING_DATE                    0
# PROD_STAFF_CONTRACTOR_HC_AMT        0
# RECRUITER_TOTAL_CONTACTS_AMT        0
# RETAIL_CONTRACTOR_HC_AMT            0
# RECRUIT_CONTRACTOR_HC_AMT           0
# RECRUITER_ACCOUNT_INTERVIEWS_AMT    0
# PRODUCER_HC                         0
# RECRUITER_EMAI_LCONTACTS_AMT        0
# RECRUITER_SERVICE_TOUCHPOINTS       0
# STAFF_CONTRACTOR_HC_AMT             0
# SSO_CONTRACTOR_HC_AMT               0
# LARGE_CORP_ACCTS_AMT                0
# CONTRACTOR_HC_AMT                   0
# FISCAL_MONTH                        0
# SERVICES_CONTRACTOR_HC_AMT          0
# RECRUITER_OFFERS_ACCEPTED_AMT       0
# SALES_MEETINGS_AMT                  0
# OFFER_ACCEPT_AMT                    0
# CLIENT_INTERVIEW_AMT                0
# STAFF_SPREAD_AMT                    0
# RECRUITER_G2S_MODIFIED_AMT          0
# NON_RECRUIT_CONTRACTOR_HC_AMT       0
# DPT_CONTRACTOR_HC_AMT               0
# SALES_COMPLETED_ACTIVITIES_AMT      0
# ...

# %%
df2['OFFER_ACCEPT_AMT'].value_counts()
# Out:
# 0      455
# 7       47
# 42      44
# 63      44
# 21      43
# 28      42
# 56      42
# 14      34
# 70      31
# 35      30
# 77      28
# 49      27
# 91      26
# 84      24
# 105     19
# 112     18
# 119     17
# 98      16
# 140     12
# 133      9
# 126      8
# 210      7
# 154      6
# 147      6
# 189      6
# 161      6
# 168      5
# 196      4
# 175      4
# 182      4
# 217      3
# 203      3
# 266      2
# 224      2
# 273      2
# 287      2
# 280      1
# 12       1
# 231      1
# 343      1
# 238      1
# 1        1
# 15       1
# 2        1
# 245      1
# Name: OFFER_ACCEPT_AMT, dtype: int64

# %%
df2['OFFER_ACCEPT']=pd.cut(df2['OFFER_ACCEPT_AMT'], [-np.inf, 1, np.inf], labels=[0, 1])

# %%
df2=df2.drop(columns='OFFER_ACCEPT_AMT')

# %%
target_column='OFFER_ACCEPT'
X, y = df2.drop(columns=target_column), df2[target_column]

# %%
y.value_counts().sort_index()
# Out:
# 0    456
# 1    631
# Name: OFFER_ACCEPT, dtype: int64

# %%
df2.to_csv('gs://laah-allegis/new_allegis3.csv', index=False)

# %%
import os

PROJECT_ID = ""

# Get your Google Cloud project ID from gcloud
if not os.getenv("IS_TESTING"):
    shell_output=!gcloud config list --format 'value(core.project)' 2>/dev/null
    PROJECT_ID = shell_output[0]
    print("Project ID: ", PROJECT_ID)
# Out:
# Project ID:  laah-vertex-pipeline

# %%
BUCKET_NAME = "gs://laah-allegis"  # @param {type:"string"}
REGION = "us-central1"  # @param {type:"string"}

# %%
import os

from google.cloud import aiplatform

aiplatform.init(project=PROJECT_ID, location=REGION)

# %%
ds = aiplatform.TabularDataset('projects/1052547690175/locations/us-central1/datasets/3375228018388631552')
'projects/1052547690175/locations/us-central1/datasets/3375228018388631552'
# Out:
# 'projects/1052547690175/locations/us-central1/datasets/3375228018388631552'

# %%
X.dtypes
# Out:
# DIVISION_NAME                                int64
# WEEK_ENDING_DATE                    datetime64[ns]
# PROD_STAFF_CONTRACTOR_HC_AMT                 int64
# RECRUITER_TOTAL_CONTACTS_AMT                 int64
# RETAIL_CONTRACTOR_HC_AMT                     int64
# RECRUIT_CONTRACTOR_HC_AMT                    int64
# RECRUITER_ACCOUNT_INTERVIEWS_AMT             int64
# PRODUCER_HC                                  int64
# RECRUITER_EMAI_LCONTACTS_AMT                 int64
# RECRUITER_SERVICE_TOUCHPOINTS                int64
# STAFF_CONTRACTOR_HC_AMT                      int64
# SSO_CONTRACTOR_HC_AMT                        int64
# LARGE_CORP_ACCTS_AMT                         int64
# CONTRACTOR_HC_AMT                            int64
# FISCAL_MONTH                                 int64
# SERVICES_CONTRACTOR_HC_AMT                   int64
# RECRUITER_OFFERS_ACCEPTED_AMT                int64
# SALES_MEETINGS_AMT                           int64
# ...

# %%
# gradient boosting for classification in scikit-learn
from numpy import mean
from numpy import std
import sklearn
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from matplotlib import pyplot
from sklearn.metrics import auc
# define dataset
#X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=1)
# evaluate the model
model = GradientBoostingClassifier()
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1, error_score='raise')
print('AUC: %.3f' % (mean(n_scores)))
# fit the model on the whole dataset
model = GradientBoostingClassifier()
model.fit(X, y)
# Out:
# AUC: 0.993
# GradientBoostingClassifier()

# %%
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
# ...
