# %%
# !pip install xgboost

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from tensorboardX) (1.21.5)
# Requirement already satisfied: protobuf>=3.8.0 in /opt/conda/lib/python3.7/site-packages (from tensorboardX) (3.19.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from tensorboardX) (1.16.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.5

# %%
# Installing the Vertex AI TensorBoard uploader

# !python -m pip install google-cloud-aiplatform['tensorboard'] --upgrade

# %%
import datetime

# %%
region = "us-central1"
display_name = 'xgboost-test'
project_id = 'laah-play'

content_name = "vertex-ai-tb-get-started"

# %%
import xgboost as xgb
#from tensorboardX import SummaryWriter

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split


X, y = load_boston(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {'objective':'reg:squarederror', 'eval_metric': 'rmse'}

bst = xgb.train(params, dtrain, num_boost_round=100, evals=[(dtrain, 'train'), (dtest, 'test')],
        callbacks=[tensorboard_callback])

# %%
import xgboost as xgb
from tensorboardX import SummaryWriter

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

def TensorBoardCallback():
    writer = SummaryWriter()
    def callback(env):
        for k, v in env.evaluation_result_list:
            writer.add_scalar(k, v, env.iteration)
    return callback

X, y = load_boston(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {'objective':'reg:squarederror', 'eval_metric': 'rmse'}

bst = xgb.train(params, dtrain, num_boost_round=100, evals=[(dtrain, 'train'), (dtest, 'test')],
        callbacks=[TensorBoardCallback()])
# Out:
# 0	train-rmse:17.11300	test-rmse:17.08377
# 1	train-rmse:12.34500	test-rmse:12.46480
# 2	train-rmse:8.98781	test-rmse:9.35747
# 3	train-rmse:6.62210	test-rmse:7.20803
# 4	train-rmse:4.94271	test-rmse:5.74796
# 5	train-rmse:3.75463	test-rmse:4.86391
# 6	train-rmse:2.92989	test-rmse:4.32932
# 7	train-rmse:2.36555	test-rmse:3.92252
# 8	train-rmse:1.95423	test-rmse:3.73362
# 9	train-rmse:1.67054	test-rmse:3.59611
# 10	train-rmse:1.44967	test-rmse:3.51951
# 11	train-rmse:1.31181	test-rmse:3.49104
# 12	train-rmse:1.20016	test-rmse:3.44372
# 13	train-rmse:1.10378	test-rmse:3.42186
# 14	train-rmse:1.03921	test-rmse:3.43211
# 15	train-rmse:0.94402	test-rmse:3.42610
# 16	train-rmse:0.91113	test-rmse:3.42878
# 17	train-rmse:0.85808	test-rmse:3.42449
# 18	train-rmse:0.81549	test-rmse:3.43473
# 19	train-rmse:0.76909	test-rmse:3.43636
# 20	train-rmse:0.71461	test-rmse:3.43201
# 21	train-rmse:0.65097	test-rmse:3.41834
# 22	train-rmse:0.61106	test-rmse:3.41115
# 23	train-rmse:0.57481	test-rmse:3.40099
# 24	train-rmse:0.52950	test-rmse:3.40059
# 25	train-rmse:0.50635	test-rmse:3.40022
# 26	train-rmse:0.47886	test-rmse:3.40026
# 27	train-rmse:0.45630	test-rmse:3.39217
# 28	train-rmse:0.44189	test-rmse:3.39319
# 29	train-rmse:0.42494	test-rmse:3.39307
# 30	train-rmse:0.41880	test-rmse:3.39250
# 31	train-rmse:0.40734	test-rmse:3.39224
# 32	train-rmse:0.39267	test-rmse:3.39104
# 33	train-rmse:0.36487	test-rmse:3.38636
# 34	train-rmse:0.35095	test-rmse:3.38826
# 35	train-rmse:0.32844	test-rmse:3.38823
# 36	train-rmse:0.32258	test-rmse:3.38768
# 37	train-rmse:0.31489	test-rmse:3.38981
# 38	train-rmse:0.30286	test-rmse:3.38724
# 39	train-rmse:0.28958	test-rmse:3.38433
# 40	train-rmse:0.27204	test-rmse:3.38174
# 41	train-rmse:0.26554	test-rmse:3.37997
# 42	train-rmse:0.26066	test-rmse:3.37847
# 43	train-rmse:0.24233	test-rmse:3.38246
# 44	train-rmse:0.23388	test-rmse:3.38112
# 45	train-rmse:0.21593	test-rmse:3.38241
# 46	train-rmse:0.20374	test-rmse:3.38051
# 47	train-rmse:0.20039	test-rmse:3.38008
# 48	train-rmse:0.19123	test-rmse:3.38258
# 49	train-rmse:0.18257	test-rmse:3.38115
# 50	train-rmse:0.17742	test-rmse:3.38248
# 51	train-rmse:0.17314	test-rmse:3.38266
# 52	train-rmse:0.15845	test-rmse:3.38248
# 53	train-rmse:0.14714	test-rmse:3.38162
# 54	train-rmse:0.14038	test-rmse:3.38116
# 55	train-rmse:0.13368	test-rmse:3.37985
# 56	train-rmse:0.13078	test-rmse:3.38068
# 57	train-rmse:0.12351	test-rmse:3.37845
# 58	train-rmse:0.11651	test-rmse:3.37893
# 59	train-rmse:0.10686	test-rmse:3.37872
# 60	train-rmse:0.10148	test-rmse:3.37975
# 61	train-rmse:0.09908	test-rmse:3.38041
# 62	train-rmse:0.09234	test-rmse:3.38252
# 63	train-rmse:0.08522	test-rmse:3.38360
# 64	train-rmse:0.08126	test-rmse:3.38317
# 65	train-rmse:0.07545	test-rmse:3.38249
# 66	train-rmse:0.07388	test-rmse:3.38309
# 67	train-rmse:0.07077	test-rmse:3.38293
# 68	train-rmse:0.06988	test-rmse:3.38305
# 69	train-rmse:0.06790	test-rmse:3.38280
# 70	train-rmse:0.06363	test-rmse:3.38293
# 71	train-rmse:0.06050	test-rmse:3.38260
# 72	train-rmse:0.05752	test-rmse:3.38259
# 73	train-rmse:0.05237	test-rmse:3.38304
# 74	train-rmse:0.05082	test-rmse:3.38301
# 75	train-rmse:0.04843	test-rmse:3.38272
# 76	train-rmse:0.04587	test-rmse:3.38292
# 77	train-rmse:0.04389	test-rmse:3.38314
# 78	train-rmse:0.04293	test-rmse:3.38329
# 79	train-rmse:0.04053	test-rmse:3.38356
# 80	train-rmse:0.03987	test-rmse:3.38359
# 81	train-rmse:0.03698	test-rmse:3.38411
# 82	train-rmse:0.03521	test-rmse:3.38393
# 83	train-rmse:0.03303	test-rmse:3.38389
# 84	train-rmse:0.03254	test-rmse:3.38408
# 85	train-rmse:0.03117	test-rmse:3.38393
# 86	train-rmse:0.02949	test-rmse:3.38401
# 87	train-rmse:0.02757	test-rmse:3.38401
# 88	train-rmse:0.02714	test-rmse:3.38393
# 89	train-rmse:0.02548	test-rmse:3.38404
# 90	train-rmse:0.02431	test-rmse:3.38394
# 91	train-rmse:0.02293	test-rmse:3.38388
# 92	train-rmse:0.02122	test-rmse:3.38365
# 93	train-rmse:0.02029	test-rmse:3.38377
# 94	train-rmse:0.02005	test-rmse:3.38387
# 95	train-rmse:0.01909	test-rmse:3.38414
# 96	train-rmse:0.01855	test-rmse:3.38409
# 97	train-rmse:0.01825	test-rmse:3.38423
# 98	train-rmse:0.01755	test-rmse:3.38423
# 99	train-rmse:0.01658	test-rmse:3.38434

# %%
import tensorflow as tf

# %%
from google.cloud import aiplatform

aiplatform.init(project=project_id, location=region)

tensorboard = aiplatform.Tensorboard.create(display_name=content_name)

TENSORBOARD_RESOURCE_NAME = tensorboard.resource_nam
# Out:
# INFO:google.cloud.aiplatform.tensorboard.tensorboard_resource:Creating Tensorboard
# INFO:google.cloud.aiplatform.tensorboard.tensorboard_resource:Create Tensorboard backing LRO: projects/959641146622/locations/us-central1/tensorboards/4798673363893485568/operations/6830432932033724416
# INFO:google.cloud.aiplatform.tensorboard.tensorboard_resource:Tensorboard created. Resource name: projects/959641146622/locations/us-central1/tensorboards/4798673363893485568
# INFO:google.cloud.aiplatform.tensorboard.tensorboard_resource:To use this Tensorboard in another session:
# INFO:google.cloud.aiplatform.tensorboard.tensorboard_resource:tb = aiplatform.Tensorboard('projects/959641146622/locations/us-central1/tensorboards/4798673363893485568')

# %%
# !tb-gcp-uploader --one_shot=True  --tensorboard_resource_name $TENSORBOARD_RESOURCE_NAME \
  -logdir=/home/jupyter/XGBoost/runs/Mar29_19-01-15_tensorflow-2-6-20220302-171927 --experiment_name="test-experiment3"
# Out:
# E0329 19:57:25.978268372   10372 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# 2022-03-29 19:57:29.255905: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-03-29 19:57:29.255957: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-29 19:57:29.255982: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tensorflow-2-6-20220302-171927): /proc/driver/nvidia/version does not exist
# View your Tensorboard at https://us-central1.tensorboard.googleusercontent.com/experiment/projects+959641146622+locations+us-central1+tensorboards+4798673363893485568+experiments+test-experiment3
# [2022-03-29T19:57:29] Started scanning logdir.
# [2022-03-29T19:57:30] Total uploaded: 200 scalars, 0 tensors, 0 binary objects
# Listening for new data in logdir...

# %%
import datetime
import os

import xgboost as xgb
from tensorboardX import SummaryWriter

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split


class TensorBoardCallback(xgb.callback.TrainingCallback):
    def __init__(self, experiment: str = None, data_name: str = None):
        self.experiment = experiment or "logs"
        self.data_name = data_name or "test"
        self.datetime_ = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
        self.log_dir = f"runs/{self.experiment}/{self.datetime_}"
        self.train_writer = SummaryWriter(log_dir=os.path.join(self.log_dir, "train/"))
        if self.data_name:
            self.test_writer = SummaryWriter(
                log_dir=os.path.join(self.log_dir, f"{self.data_name}/")
            )

    def after_iteration(
        self, model, epoch: int, evals_log: xgb.callback.TrainingCallback.EvalsLog
    ) -> bool:
        if not evals_log:
            return False

        for data, metric in evals_log.items():
            for metric_name, log in metric.items():
                score = log[-1][0] if isinstance(log[-1], tuple) else log[-1]
                if data == "train":
                    self.train_writer.add_scalar(metric_name, score, epoch)
                else:
                    self.test_writer.add_scalar(metric_name, score, epoch)

        return False


X, y = load_boston(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {'objective':'reg:squarederror', 'eval_metric': 'rmse'}

bst = xgb.train(params, dtrain, num_boost_round=100, evals=[(dtrain, 'train'), (dtest, 'test')],
        callbacks=[TensorBoardCallback(experiment='exp_1', data_name='test')])
# Out:
# [0]	train-rmse:17.11300	test-rmse:17.08377
# [1]	train-rmse:12.34500	test-rmse:12.46480
# [2]	train-rmse:8.98781	test-rmse:9.35747
# [3]	train-rmse:6.62210	test-rmse:7.20803
# [4]	train-rmse:4.94271	test-rmse:5.74796
# [5]	train-rmse:3.75463	test-rmse:4.86391
# [6]	train-rmse:2.92989	test-rmse:4.32932
# [7]	train-rmse:2.36555	test-rmse:3.92252
# [8]	train-rmse:1.95423	test-rmse:3.73362
# [9]	train-rmse:1.67054	test-rmse:3.59611
# [10]	train-rmse:1.44967	test-rmse:3.51951
# [11]	train-rmse:1.31181	test-rmse:3.49104
# [12]	train-rmse:1.20016	test-rmse:3.44372
# [13]	train-rmse:1.10378	test-rmse:3.42186
# [14]	train-rmse:1.03921	test-rmse:3.43211
# [15]	train-rmse:0.94402	test-rmse:3.42610
# [16]	train-rmse:0.91113	test-rmse:3.42878
# [17]	train-rmse:0.85808	test-rmse:3.42449
# [18]	train-rmse:0.81549	test-rmse:3.43473
# [19]	train-rmse:0.76909	test-rmse:3.43636
# [20]	train-rmse:0.71461	test-rmse:3.43201
# [21]	train-rmse:0.65097	test-rmse:3.41834
# [22]	train-rmse:0.61106	test-rmse:3.41115
# [23]	train-rmse:0.57481	test-rmse:3.40099
# [24]	train-rmse:0.52950	test-rmse:3.40059
# [25]	train-rmse:0.50635	test-rmse:3.40022
# [26]	train-rmse:0.47886	test-rmse:3.40026
# [27]	train-rmse:0.45630	test-rmse:3.39217
# [28]	train-rmse:0.44189	test-rmse:3.39319
# [29]	train-rmse:0.42494	test-rmse:3.39307
# [30]	train-rmse:0.41880	test-rmse:3.39250
# [31]	train-rmse:0.40734	test-rmse:3.39224
# [32]	train-rmse:0.39267	test-rmse:3.39104
# [33]	train-rmse:0.36487	test-rmse:3.38636
# [34]	train-rmse:0.35095	test-rmse:3.38826
# [35]	train-rmse:0.32844	test-rmse:3.38823
# [36]	train-rmse:0.32258	test-rmse:3.38768
# [37]	train-rmse:0.31489	test-rmse:3.38981
# [38]	train-rmse:0.30286	test-rmse:3.38724
# [39]	train-rmse:0.28958	test-rmse:3.38433
# [40]	train-rmse:0.27204	test-rmse:3.38174
# [41]	train-rmse:0.26554	test-rmse:3.37997
# [42]	train-rmse:0.26066	test-rmse:3.37847
# [43]	train-rmse:0.24233	test-rmse:3.38246
# [44]	train-rmse:0.23388	test-rmse:3.38112
# [45]	train-rmse:0.21593	test-rmse:3.38241
# [46]	train-rmse:0.20374	test-rmse:3.38051
# [47]	train-rmse:0.20039	test-rmse:3.38008
# [48]	train-rmse:0.19123	test-rmse:3.38258
# [49]	train-rmse:0.18257	test-rmse:3.38115
# [50]	train-rmse:0.17742	test-rmse:3.38248
# [51]	train-rmse:0.17314	test-rmse:3.38266
# [52]	train-rmse:0.15845	test-rmse:3.38248
# [53]	train-rmse:0.14714	test-rmse:3.38162
# [54]	train-rmse:0.14038	test-rmse:3.38116
# [55]	train-rmse:0.13368	test-rmse:3.37985
# [56]	train-rmse:0.13078	test-rmse:3.38068
# [57]	train-rmse:0.12351	test-rmse:3.37845
# [58]	train-rmse:0.11651	test-rmse:3.37893
# [59]	train-rmse:0.10686	test-rmse:3.37872
# [60]	train-rmse:0.10148	test-rmse:3.37975
# [61]	train-rmse:0.09908	test-rmse:3.38041
# [62]	train-rmse:0.09234	test-rmse:3.38252
# [63]	train-rmse:0.08522	test-rmse:3.38360
# [64]	train-rmse:0.08126	test-rmse:3.38317
# [65]	train-rmse:0.07545	test-rmse:3.38249
# [66]	train-rmse:0.07388	test-rmse:3.38309
# [67]	train-rmse:0.07077	test-rmse:3.38293
# [68]	train-rmse:0.06988	test-rmse:3.38305
# [69]	train-rmse:0.06790	test-rmse:3.38280
# [70]	train-rmse:0.06363	test-rmse:3.38293
# [71]	train-rmse:0.06050	test-rmse:3.38260
# [72]	train-rmse:0.05752	test-rmse:3.38259
# [73]	train-rmse:0.05237	test-rmse:3.38304
# [74]	train-rmse:0.05082	test-rmse:3.38301
# [75]	train-rmse:0.04843	test-rmse:3.38272
# [76]	train-rmse:0.04587	test-rmse:3.38292
# [77]	train-rmse:0.04389	test-rmse:3.38314
# [78]	train-rmse:0.04293	test-rmse:3.38329
# [79]	train-rmse:0.04053	test-rmse:3.38356
# [80]	train-rmse:0.03987	test-rmse:3.38359
# [81]	train-rmse:0.03698	test-rmse:3.38411
# [82]	train-rmse:0.03521	test-rmse:3.38393
# [83]	train-rmse:0.03303	test-rmse:3.38389
# [84]	train-rmse:0.03254	test-rmse:3.38408
# [85]	train-rmse:0.03117	test-rmse:3.38393
# [86]	train-rmse:0.02949	test-rmse:3.38401
# [87]	train-rmse:0.02757	test-rmse:3.38401
# [88]	train-rmse:0.02714	test-rmse:3.38393
# [89]	train-rmse:0.02548	test-rmse:3.38404
# [90]	train-rmse:0.02431	test-rmse:3.38394
# [91]	train-rmse:0.02293	test-rmse:3.38388
# [92]	train-rmse:0.02122	test-rmse:3.38365
# [93]	train-rmse:0.02029	test-rmse:3.38377
# [94]	train-rmse:0.02005	test-rmse:3.38387
# [95]	train-rmse:0.01909	test-rmse:3.38414
# [96]	train-rmse:0.01855	test-rmse:3.38409
# [97]	train-rmse:0.01825	test-rmse:3.38423
# [98]	train-rmse:0.01755	test-rmse:3.38423
# [99]	train-rmse:0.01658	test-rmse:3.38434

# %%
# !tb-gcp-uploader --help
# Out:
# E0329 19:27:04.148275011   10372 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
#        USAGE: /opt/conda/bin/tb-gcp-uploader [flags]
# flags:
#
# /opt/conda/bin/tb-gcp-uploader:
#   --allowed_plugins: Plugins allowed by the Uploader.;
#     repeat this option to specify a list of values
#     (default: "['scalars', 'histograms', 'distributions', 'text', 'hparams',
#     'images', 'graphs']")
#   --api_uri: The API URI for fetching Tensorboard metadata.
#     (default: 'aiplatform.googleapis.com')
#   --env: Environment which this tensorboard belongs to.
#     (default: 'prod')
#   --event_file_inactive_secs: Age in seconds of last write after which an event
#     file is considered inactive.
#     (an integer)
#   --experiment_display_name: The display name of the Cloud AI Experiment.
#   --experiment_name: The name of the Cloud AI Experiment.
#   --logdir: Tensorboard log directory to upload
#   --[no]one_shot: Iterate through logdir once to upload.
#     (default: 'false')
#   --run_name_prefix: If present, all runs created by this invocation will have
#     their name prefixed by this value.
#   --tensorboard_resource_name: Tensorboard resource to create this experiment
#     in.
#   --web_server_uri: The API URI for accessing the Tensorboard UI.
#     (default: 'tensorboard.googleusercontent.com')
#
# Try --helpfull to get a list of all flags.

# %%
# !tensorboard --inspect --logdir=/home/jupyter/XGBoost/runs/exp_1
# Out:
# E0329 19:45:47.916343689   10372 fork_posix.cc:70]           Fork support is only compatible with the epoll1 and poll polling strategies
# 2022-03-29 19:45:50.719738: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64
# 2022-03-29 19:45:50.719792: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-29 19:45:50.719815: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tensorflow-2-6-20220302-171927): /proc/driver/nvidia/version does not exist
# ======================================================================
# Processing event files... (this can take a few minutes)
# ======================================================================
#
# Found event files in:
# /home/jupyter/XGBoost/runs/exp_1/20220329-190537/test
# /home/jupyter/XGBoost/runs/exp_1/20220329-190537/train
#
# These tags are in /home/jupyter/XGBoost/runs/exp_1/20220329-190537/test:
# audio -
# histograms -
# images -
# scalars
#    rmse
# tensor -
# ======================================================================
#
# Event statistics for /home/jupyter/XGBoost/runs/exp_1/20220329-190537/test:
# audio -
# graph -
# histograms -
# images -
# scalars
#    first_step           0
#    last_step            99
#    max_step             99
#    min_step             0
#    num_steps            100
#    outoforder_steps     []
# sessionlog:checkpoint -
# sessionlog:start -
# sessionlog:stop -
# tensor -
# ======================================================================
#
# These tags are in /home/jupyter/XGBoost/runs/exp_1/20220329-190537/train:
# audio -
# histograms -
# images -
# scalars
#    rmse
# tensor -
# ======================================================================
#
# Event statistics for /home/jupyter/XGBoost/runs/exp_1/20220329-190537/train:
# audio -
# graph -
# histograms -
# images -
# scalars
#    first_step           0
#    last_step            99
#    max_step             99
#    min_step             0
#    num_steps            100
#    outoforder_steps     []
# sessionlog:checkpoint -
# sessionlog:start -
# sessionlog:stop -
# tensor -
# ======================================================================
